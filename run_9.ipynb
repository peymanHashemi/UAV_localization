# %%
with open(f"all_results.txt", "a") as F:
        F.write(" ---------------------- Day 9 ----------------------\n")

# %%
# !bash train_test_local_ruz_9_1.sh

# %%
# !bash train_test_local_ruz_9_2.sh

# %%
# !mv checkpoints/* "../../results/Day 9"

# %%
# !bash dual_train_test_local.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_dual', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', seg_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/segment', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.01, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=120, num_bottleneck=512, load_from='no', backbone='vit_small_patch16_224.augreg_in21k_ft_in1k', head='SingleBranch', head_pool='avg', lr_step1=70, lr_step2=110, lr_step3=2000, lr_step4=4000, val_step=2, segmentaion='True', seg_backbone='cvt13', seg_val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/seg_val')
# ...
