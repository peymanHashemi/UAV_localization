# %%
with open(f"all_results.txt", "a") as F:
        F.write(" ---------------------- Day 4 ----------------------\n")

# %%
# !bash train_test_local_ruz_4_1.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__015__150__60_100', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.015, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='mvitv2_base.fb_in1k', head='SingleBranch', head_pool='avg', lr_step1=60, lr_step2=100, lr_step3=2000, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x7f2e977bd5d0>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !bash train_test_local_ruz_4_2.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_1k__0175__150__55_110', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.0175, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='mvitv2_base.fb_in1k', head='SingleBranch', head_pool='avg', lr_step1=55, lr_step2=110, lr_step3=2000, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x76f45425d600>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !mv checkpoints/* "../../results/Day 4"
