# %%
with open(f"all_results.txt", "a") as F:
        F.write(" ---------------------- Day 3 ----------------------\n")

# %%
# !bash train_test_local_ruz_3_1.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__005__250__80_130_190', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.005, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=250, num_bottleneck=512, load_from='no', backbone='mvitv2_base_cls.fb_inw21k', head='SingleBranch', head_pool='avg', lr_step1=80, lr_step2=130, lr_step3=190, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x79b1ffe5d5d0>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !bash train_test_local_ruz_3_2.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__0125__250__60_100_170', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.0125, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=250, num_bottleneck=512, load_from='no', backbone='mvitv2_base_cls.fb_inw21k', head='SingleBranch', head_pool='avg', lr_step1=60, lr_step2=100, lr_step3=170, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x7bab4ae255d0>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !mv checkpoints/* "../../results/Day 3"
