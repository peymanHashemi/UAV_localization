# %%
with open(f"all_results.txt", "a") as F:
        F.write(" ---------------------- Day 0 ----------------------\n")

# %%
# !bash train_test_local_ruz_0_1.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='vit_s_p16_21k_1k__015__150__60_100', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.015, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='vit_small_patch16_224.augreg_in21k_ft_in1k', head='SingleBranch', head_pool='avg', lr_step1=60, lr_step2=100, lr_step3=2000, lr_step4=4000, val_step=2)
# ...

# %%
# !bash train_test_local_ruz_0_2.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='vit_s_p16_21k_1k__01__150__75_120', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.01, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='vit_small_patch16_224.augreg_in21k_ft_in1k', head='SingleBranch', head_pool='avg', lr_step1=75, lr_step2=120, lr_step3=2000, lr_step4=4000, val_step=2)
# ...

# %%
# !mv checkpoints/* "../../results/Day 0"

# %%
with open(f"all_results.txt", "a") as F:
        F.write(" ---------------------- Day 1 ----------------------\n")

# %%
# !bash train_test_local_ruz_1_1.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__015__150__60_100', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.015, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='mvitv2_base_cls.fb_inw21k', head='SingleBranch', head_pool='avg', lr_step1=60, lr_step2=100, lr_step3=2000, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x7c79af0f15d0>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !ls
# Out:
#  all_results.txt		   run_9.ipynb
#  batch_inference_time.sh	   run.ipynb
#  checkpoints			   test_hard.py
#  cuda_11.8.0_520.61.05_linux.run   test.py
#  datasets			   tool
#  docs				   train.py
#  evaluateDistance_DifHeight.py	   train_test_local2.sh
#  evaluateDistance.py		   train_test_local_ruz_0_1.sh
#  evaluate_gpu.py		   train_test_local_ruz_0_2.sh
#  evaluateMA_dense.py		   train_test_local_ruz_1_1.sh
#  evaluateMA.py			  'train_test_local_ruz_ 1_2.sh'
#  evaluate_RDS.py		  'train_test_local_ruz_ 2_1.sh'
#  heatmap.py			  'train_test_local_ruz_ 2_2.sh'
#  LICENSE			  'train_test_local_ruz_ 3_1.sh'
#  losses				  'train_test_local_ruz_ 3_2.sh'
#  models				  'train_test_local_ruz_ 4_1.sh'
#  optimizers			  'train_test_local_ruz_ 4_2.sh'
#  __pycache__			  'train_test_local_ruz_ 5_1.sh'
#  pytorch-image-models		  'train_test_local_ruz_ 5_2.sh'
#  README.md			  'train_test_local_ruz_ 6_1.sh'
#  re.bash			  'train_test_local_ruz_ 6_2.sh'
# ...

# %%
# !bash 'train_test_local_ruz_ 1_2.sh'
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__0175__150__60_100', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.0175, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='mvitv2_base_cls.fb_inw21k', head='SingleBranch', head_pool='avg', lr_step1=60, lr_step2=100, lr_step3=2000, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x7db867c5d600>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !mv checkpoints/* "../../results/Day 1"
