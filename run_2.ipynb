# %%
with open(f"all_results.txt", "a") as F:
        F.write(" ---------------------- Day 2 ----------------------\n")

# %%
# !bash train_test_local_ruz_2_1.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__015__150__50_90', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.015, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=150, num_bottleneck=512, load_from='no', backbone='mvitv2_base_cls.fb_inw21k', head='SingleBranch', head_pool='avg', lr_step1=50, lr_step2=90, lr_step3=2000, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x7cdedab2d5a0>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !bash train_test_local_ruz_2_2.sh
# Out:
# Namespace(gpu_ids='0', checkpoint='net.pth', name='mvit_b_21k__0075__200__70_130', data_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/train', val_dir='/home/abbas/AUT/Dataset/DenseUAV/google2/validation', ms='1', mode=1, num_worker=8, batchsize=16, pad=0, h=224, w=224, rr='uav', ra='satellite', re='satellite', cj='no', erasing_p=0.3, warm_epoch=0, lr=0.0075, DA=False, droprate=0.5, autocast=True, block=1, cls_loss='CELoss', feature_loss='WeightedSoftTripletLoss', kl_loss='KLLoss', sample_num=1, num_epochs=200, num_bottleneck=512, load_from='no', backbone='mvitv2_base_cls.fb_inw21k', head='SingleBranch', head_pool='avg', lr_step1=70, lr_step2=130, lr_step3=2000, lr_step4=4000, val_step=2)
# [<datasets.queryDataset.RotateAndCrop object at 0x71f4efb5d600>, Resize(size=(224, 224), interpolation=bicubic, max_size=None, antialias=True), Pad(padding=0, fill=0, padding_mode=edge), RandomHorizontalFlip(p=0.5), ToTensor(), Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])]
# ...

# %%
# !mv checkpoints/* "../../results/Day 2"
